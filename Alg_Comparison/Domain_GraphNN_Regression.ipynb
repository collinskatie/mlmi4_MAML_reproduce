# %% [markdown]
# <h1> Imports and Installs

# %%
# Install required packages.
# !pip3 install -q torch-scatter -f https://pytorch-geometric.com/whl/torch-1.10.0+cu113.html
# !pip3 install -q torch-sparse -f https://pytorch-geometric.com/whl/torch-1.10.0+cu113.html
# !pip3 install -q git+https://github.com/rusty1s/pytorch_geometric.git

# %%
import matplotlib.pyplot as plt
import numpy as np

# Required imports for neural network
import torch.nn as nn
import torch
from torch.autograd import Variable
import random

# For GNNs
from torch.nn import Linear
from torch.nn import BatchNorm1d
import torch.nn.functional as F
from torch_geometric.nn import GATConv
from torch_geometric.nn import GraphConv
from torch_geometric.nn import GraphNorm
from torch_geometric.nn import global_mean_pool
from torch_geometric.nn import global_max_pool
import torch.nn as nn

domain_type = "graph_reg"

# %%
# !pip3 install higher

from higher import innerloop_ctx

import warnings
#The code includes extensive warnings when run so have used this to ignore them
warnings.filterwarnings("ignore")

#Set random seeds for reproducibility of results 
torch.manual_seed(0)
random.seed(0)
np.random.seed(0)

# set GPU or CPU depending on available hardware
# help from: https://stackoverflow.com/questions/46704352/porting-pytorch-code-from-cpu-to-gpu
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Available device: {device}")

if device == "cuda:0": 
  # set default so all tensors are on GPU, if available
  # help from: https://stackoverflow.com/questions/46704352/porting-pytorch-code-from-cpu-to-gpu
  torch.set_default_tensor_type('torch.cuda.FloatTensor')
# Out:
# Requirement already satisfied: higher in /Users/kcollins/opt/anaconda3/lib/python3.8/site-packages (0.2.1)
# Requirement already satisfied: torch in /Users/kcollins/opt/anaconda3/lib/python3.8/site-packages (from higher) (1.10.2)
# Requirement already satisfied: typing-extensions in /Users/kcollins/opt/anaconda3/lib/python3.8/site-packages (from torch->higher) (3.7.4.3)
# Available device: cpu

# %% [markdown]
# <h1> Data Loading and Generation
#
# Reptile for regression task using GNNs
#
# Some common GNN datasets are here:
# https://pytorch-geometric.readthedocs.io/en/latest/modules/datasets.html#torch_geometric.datasets.GNNBenchmarkDataset
#
# We will use a regression dataset with 19 regression targets from the paper:
# “MoleculeNet: A Benchmark for Molecular Machine Learning”

# %% [markdown]
# For this implementation we focus on regressing only the Dipole moment

# %%
from torch_geometric.datasets import QM9

dataset = QM9(root='data/QM9')
# Out:
# Downloading https://data.pyg.org/datasets/qm9_v3.zip
# Extracting data/QM9/raw/qm9_v3.zip
# Processing...
# Using a pre-processed version of the dataset. Please install 'rdkit' to alternatively process the raw data.
# Done!

# %%
# This function is based on https://pytorch-geometric.readthedocs.io/en/latest/notes/colabs.html

#Function to display properties of the dataset (it is not necessary for anything)
def display_graph_dataset_properties(dataset):
  print()
  print(f'Dataset: {dataset}:')
  print('====================')
  print(f'Number of graphs: {len(dataset)}')
  print(f'Number of features: {dataset.num_features}')
  print(f'Number of classes: {dataset.num_classes}')

  data = dataset[0]  # Get the first graph object.Ç

  print()
  print('Look at a sample graph of the dataset')
  print(data)
  print('=============================================================')

  # Gather some statistics about the first graph.
  print(f'Number of nodes: {data.num_nodes}')
  print(f'Number of edges: {data.num_edges}')
  print(f'Average node degree: {data.num_edges / data.num_nodes:.2f}')
  print(f'Has isolated nodes: {data.has_isolated_nodes()}')
  print(f'Has self-loops: {data.has_self_loops()}')
  print(f'Is undirected: {data.is_undirected()}')

# %%
display_graph_dataset_properties(dataset)
# Out:
# Dataset: QM9(130831):
# ====================
# Number of graphs: 130831
# Number of features: 11
# Number of classes: 19
#
# Look at a sample graph of the dataset
# Data(x=[5, 11], edge_index=[2, 8], edge_attr=[8, 4], y=[1, 19], pos=[5, 3], idx=[1], name='gdb_1', z=[5])
# =============================================================
# Number of nodes: 5
# Number of edges: 8
# Average node degree: 1.60
# Has isolated nodes: False
# Has self-loops: False
# Is undirected: True

# %%
# Transform the dataset into a list
dataset_list = []

for i in range(len(dataset)):
  dataset_list.append(dataset[i])

# %%
#Shuffle the dataset list
random.shuffle(dataset_list)
#Split into train and test
GRAPH_TRAIN = dataset_list[:int(np.floor(len(dataset_list)*0.9))]
GRAPH_TEST = dataset_list[int(np.floor(len(dataset_list)*0.9)):]

# %% [markdown]
# <h1> Neural Network Model

# %%
class GNN(torch.nn.Module):
    def __init__(self, input_dim=11, hidden_dim=100, output_dim=1):
        super(GNN, self).__init__()

        #Hidden Layers
        self.hidden1 = GraphConv(input_dim, hidden_dim)
        self.hidden2 = GraphConv(hidden_dim, hidden_dim)
        self.hidden3 = GraphConv(hidden_dim, output_dim)
        self.norm = GraphNorm(hidden_dim)

        #Activation Function
        self.relu = nn.ReLU()

        

    def forward(self, input_x, edge_index, batch):
      
        #Standard forward
        x = self.hidden1(input_x,edge_index)
        x = self.norm(x)
        x = self.relu(x)
        x = self.hidden2(x,edge_index)
        x = self.norm(x)
        x = self.relu(x)
        x = self.hidden3(x,edge_index)
        x = self.relu(x)

        #Global mean pool across batches
        x = global_max_pool(x, batch)

        
        return x

# %% [markdown]
# <h1> Helper functions

# %%
# The Minimum Square Error is used to evaluate the difference between prediction and ground truth
criterion = nn.MSELoss()

def copy_existing_model(model):
    # Function to copy an existing model
    # We initialize a new model
    new_model = GNN()
    # Copy the previous model's parameters into the new model
    new_model.load_state_dict(model.state_dict())
    return new_model

def initialization_to_store_meta_losses():
  # This function creates lists to store the meta losses
  global store_train_loss_meta; store_train_loss_meta = []
  global store_test_loss_meta; store_test_loss_meta = []

def test_set_validation(model,new_model,graph,lr_inner,k,store_test_loss_meta):
    # This functions does not actually affect the main algorithm, it is just used to evaluate the new model
    new_model = training(model, graph, lr_inner, k)
    # Obtain the loss
    loss = evaluation(new_model, graph)
    # Store loss
    store_test_loss_meta.append(loss)

def train_set_evaluation(new_model,graph,store_train_loss_meta):
    loss = evaluation(new_model, graph)
    store_train_loss_meta.append(loss) 

def print_losses(epoch,store_train_loss_meta,store_test_loss_meta,printing_step=1000):
  if epoch % printing_step == 0:
    print(f'Epochh : {epoch}, Average Train Meta Loss : {np.mean(store_train_loss_meta)}, Average Test Meta Loss : {np.mean(store_test_loss_meta)}')

#This is based on the paper update rule, we calculate the difference between parameters and then this is used by the optimizer, rather than doing the update by hand
def reptile_parameter_update(model,new_model):
  # Zip models for the loop
  zip_models = zip(model.parameters(), new_model.parameters())
  for parameter, new_parameter in zip_models:
    if parameter.grad is None:
      parameter.grad = torch.tensor(torch.zeros_like(parameter))
    # Here we are adding the gradient that will later be used by the optimizer
    parameter.grad.data.add_(parameter.data - new_parameter.data)

# Define commands in order needed for the metaupdate
# Note that if we change the order it doesn't behave the same
def metaoptimizer_update(metaoptimizer):
  # Take step
  metaoptimizer.step()
  # Reset gradients
  metaoptimizer.zero_grad()

def metaupdate(model,new_model,metaoptimizer):
  # Combine the two previous functions into a single metaupdate function
  # First we calculate the gradients
  reptile_parameter_update(model,new_model)
  # Use those gradients in the optimizer
  metaoptimizer_update(metaoptimizer)

def evaluation(new_model, graph, item = True):
    # Make model prediction
    prediction = new_model(graph.x,graph.edge_index,graph.batch)
    # Get loss
    if item == True: #Depending on whether we need to return the loss value for storing or for backprop
      loss = criterion(prediction,graph.y[:,0:1]).item()
    else:
      loss = criterion(prediction,graph.y[:,0:1])
    return loss

def training(model, graph, lr_k, k):
    # Create new model which we will train on
    new_model = copy_existing_model(model)
    # Define new optimizer
    koptimizer = torch.optim.SGD(new_model.parameters(), lr=lr_k)
    # Update the model multiple times, note that k>1 (do not confuse k with K)
    for i in range(k):
        # Reset optimizer
        koptimizer.zero_grad()
        # Evaluate the model
        loss = evaluation(new_model, graph, item = False)
        # Backpropagate
        loss.backward()
        koptimizer.step()
    return new_model

# for MAML -- see MAML cell for additional citations around structure inspiration
def task_specific_train_and_eval(model, T_i, inner_loop_optimizer, N=1):
    #Description of the loop formulation from https://higher.readthedocs.io/en/latest/toplevel.html
    with innerloop_ctx(model, inner_loop_optimizer, copy_initial_weights = False) as (fmodel,diffopt):
        #get our input data and our label
        per_step_loss = []
        for _ in range(N):
            
            task_specifc_loss = evaluation(fmodel, T_i, item=False)
            
            #Step through the inner gradient
            diffopt.step(task_specifc_loss)
            
            per_step_loss.append(task_specifc_loss.item())
            
        held_out_task_specific_loss = evaluation(fmodel, T_i, item=False)
        
        return held_out_task_specific_loss, per_step_loss, fmodel

# %% [markdown]
# <h1> Reptile

# %%
#Define important variables
epochs = int(1e5) # number of epochs 
lr_meta=0.002 # Learning rate for meta model (outer loop)
printing_step=100 # how many epochs should we wait to print the loss
lr_k=0.01 # Internal learning rate
k=5 # Number of internal updates for each task

# Initializations
initialization_to_store_meta_losses()
model = GNN()
metaoptimizer = torch.optim.Adam(model.parameters(), lr=lr_meta)

# %%
# Training loop
for epoch in range(epochs):
        
    # Sample a sine graph (Task from training data)
    graph = random.sample(GRAPH_TRAIN, 1)

    # Update model predefined number of times based on k
    new_model = training(model, graph[0], lr_k, k)

    # Evalaute the loss for the training data
    train_set_evaluation(new_model,graph[0],store_train_loss_meta)     
    
    #Meta-update --> Get gradient for meta loop and update
    metaupdate(model,new_model,metaoptimizer)
    
    # Evalaute the loss for the test data
    # Note that we need to sample the graph from the test data
    graph = random.sample(GRAPH_TEST, 1)
    test_set_validation(model,new_model,graph[0],lr_k,k,store_test_loss_meta)

    # Print losses every 'printing_step' epochs
    print_losses(epoch,store_train_loss_meta,store_test_loss_meta,printing_step)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:39: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# Epochh : 0, Average Train Meta Loss : 5.328248977661133, Average Test Meta Loss : 3.298945903778076
# Epochh : 100, Average Train Meta Loss : 3.3397514982906316, Average Test Meta Loss : 3.8114268442043757
# Epochh : 200, Average Train Meta Loss : 3.1520920395479957, Average Test Meta Loss : 2.2178760767721806
# Epochh : 300, Average Train Meta Loss : 2.1136855435280655, Average Test Meta Loss : 1.5064629653265378
# Epochh : 400, Average Train Meta Loss : 1.5962906348657746, Average Test Meta Loss : 1.1395248406112735
# Epochh : 500, Average Train Meta Loss : 1.2933888619772789, Average Test Meta Loss : 0.9277076123549771
# Epochh : 600, Average Train Meta Loss : 1.114435623304068, Average Test Meta Loss : 0.8581513044687483
# Epochh : 700, Average Train Meta Loss : 0.9630511390523726, Average Test Meta Loss : 0.7391521924493508
# Epochh : 800, Average Train Meta Loss : 0.8441240252191491, Average Test Meta Loss : 0.6677494034806
# Epochh : 900, Average Train Meta Loss : 0.774058696558652, Average Test Meta Loss : 0.5961247267938126
# Epochh : 1000, Average Train Meta Loss : 0.7147127237927856, Average Test Meta Loss : 0.5373508580926717
# Epochh : 1100, Average Train Meta Loss : 0.6507107166687741, Average Test Meta Loss : 0.4970374251965495
# Epochh : 1200, Average Train Meta Loss : 0.596977398278431, Average Test Meta Loss : 0.4562678015629855
# Epochh : 1300, Average Train Meta Loss : 0.5516065315353206, Average Test Meta Loss : 0.42149768857302033
# Epochh : 1400, Average Train Meta Loss : 0.5163659918669375, Average Test Meta Loss : 0.39239518364913756
# Epochh : 1500, Average Train Meta Loss : 0.4820828882594711, Average Test Meta Loss : 0.36674962928754096
# Epochh : 1600, Average Train Meta Loss : 0.4523385205554591, Average Test Meta Loss : 0.3439270323430798
# Epochh : 1700, Average Train Meta Loss : 0.4372883075958251, Average Test Meta Loss : 0.32448768697914665
# Epochh : 1800, Average Train Meta Loss : 0.415335138076481, Average Test Meta Loss : 0.30770051069046467
# Epochh : 1900, Average Train Meta Loss : 0.3935884636384143, Average Test Meta Loss : 0.2925327487194398
# Epochh : 2000, Average Train Meta Loss : 0.3740280247024355, Average Test Meta Loss : 0.27805218681408483
# Epochh : 2100, Average Train Meta Loss : 0.35672833121336134, Average Test Meta Loss : 0.265775798663788
# Epochh : 2200, Average Train Meta Loss : 0.34293268776562624, Average Test Meta Loss : 0.25444211662643074
# Epochh : 2300, Average Train Meta Loss : 0.3280325435218628, Average Test Meta Loss : 0.24348170537182093
# Epochh : 2400, Average Train Meta Loss : 0.3145722713551268, Average Test Meta Loss : 0.2338107641294156
# Epochh : 2500, Average Train Meta Loss : 0.30213147125575907, Average Test Meta Loss : 0.23158823460387362
# Epochh : 2600, Average Train Meta Loss : 0.29095461900102354, Average Test Meta Loss : 0.22276423198580556
# Epochh : 2700, Average Train Meta Loss : 0.2804687877247466, Average Test Meta Loss : 0.214636110011034
# Epochh : 2800, Average Train Meta Loss : 0.270532855501483, Average Test Meta Loss : 0.2070751051819596
# Epochh : 2900, Average Train Meta Loss : 0.26123442423501353, Average Test Meta Loss : 0.19994293206359678
# Epochh : 3000, Average Train Meta Loss : 0.2526196405167985, Average Test Meta Loss : 0.19337077607774286
# Epochh : 3100, Average Train Meta Loss : 0.24451301940565515, Average Test Meta Loss : 0.18729604752230664
# Epochh : 3200, Average Train Meta Loss : 0.23702955359734607, Average Test Meta Loss : 0.18152734468138573
# Epochh : 3300, Average Train Meta Loss : 0.22992815570433378, Average Test Meta Loss : 0.17612925476067998
# Epochh : 3400, Average Train Meta Loss : 0.22322167430668838, Average Test Meta Loss : 0.1710925794713698
# Epochh : 3500, Average Train Meta Loss : 0.21686527870557287, Average Test Meta Loss : 0.1662215916107125
# Epochh : 3600, Average Train Meta Loss : 0.2109143861125819, Average Test Meta Loss : 0.1616831760804852
# Epochh : 3700, Average Train Meta Loss : 0.2053088719755602, Average Test Meta Loss : 0.15803396456456256
# Epochh : 3800, Average Train Meta Loss : 0.2001430336133722, Average Test Meta Loss : 0.15389502407860445
# Epochh : 3900, Average Train Meta Loss : 0.19524533356405238, Average Test Meta Loss : 0.14999429515487
# Epochh : 4000, Average Train Meta Loss : 0.1912199360347778, Average Test Meta Loss : 0.1464944687523814
# Epochh : 4100, Average Train Meta Loss : 0.18663904963104241, Average Test Meta Loss : 0.14313770921144436
# Epochh : 4200, Average Train Meta Loss : 0.18238988790076038, Average Test Meta Loss : 0.1398401365360058
# Epochh : 4300, Average Train Meta Loss : 0.17815030347596822, Average Test Meta Loss : 0.1365959811613102
# Epochh : 4400, Average Train Meta Loss : 0.17411672297422418, Average Test Meta Loss : 0.1337038486545819
# Epochh : 4500, Average Train Meta Loss : 0.17205758936898524, Average Test Meta Loss : 0.1315677603672703
# Epochh : 4600, Average Train Meta Loss : 0.1684362247491157, Average Test Meta Loss : 0.12877430000555334
# Epochh : 4700, Average Train Meta Loss : 0.16500788776501793, Average Test Meta Loss : 0.12604691727430908
# Epochh : 4800, Average Train Meta Loss : 0.16157468768860472, Average Test Meta Loss : 0.12342912307865114
# Epochh : 4900, Average Train Meta Loss : 0.158368043472872, Average Test Meta Loss : 0.12092514199434676
# Epochh : 5000, Average Train Meta Loss : 0.15523835071756883, Average Test Meta Loss : 0.11850765421128254
# Epochh : 5100, Average Train Meta Loss : 0.1523004381194444, Average Test Meta Loss : 0.11626762970174523
# Epochh : 5200, Average Train Meta Loss : 0.14937649595306945, Average Test Meta Loss : 0.11407810753742663
# Epochh : 5300, Average Train Meta Loss : 0.14659875636644898, Average Test Meta Loss : 0.11196126368894069
# Epochh : 5400, Average Train Meta Loss : 0.1438916103028909, Average Test Meta Loss : 0.10996836314964392
# Epochh : 5500, Average Train Meta Loss : 0.14129491619532492, Average Test Meta Loss : 0.10804874028012934
# Epochh : 5600, Average Train Meta Loss : 0.13879034777834665, Average Test Meta Loss : 0.10614236993682517
# Epochh : 5700, Average Train Meta Loss : 0.1363729459042304, Average Test Meta Loss : 0.10429466086113148
# Epochh : 5800, Average Train Meta Loss : 0.13405377688075518, Average Test Meta Loss : 0.1024991580164703
# Epochh : 5900, Average Train Meta Loss : 0.13186593922195672, Average Test Meta Loss : 0.10078701604186376
# Epochh : 6000, Average Train Meta Loss : 0.1298726902904225, Average Test Meta Loss : 0.09910925334957435
# Epochh : 6100, Average Train Meta Loss : 0.12777721071006157, Average Test Meta Loss : 0.09748682684841399
# Epochh : 6200, Average Train Meta Loss : 0.12571699838928316, Average Test Meta Loss : 0.09592010547573727
# Epochh : 6300, Average Train Meta Loss : 0.12372558976888082, Average Test Meta Loss : 0.09439817911646516
# Epochh : 6400, Average Train Meta Loss : 0.12183915912246363, Average Test Meta Loss : 0.09292422093484237
# Epochh : 6500, Average Train Meta Loss : 0.11997180949552552, Average Test Meta Loss : 0.09183923748808816
# Epochh : 6600, Average Train Meta Loss : 0.12054167412193492, Average Test Meta Loss : 0.09045651741507352
# Epochh : 6700, Average Train Meta Loss : 0.11882297780699538, Average Test Meta Loss : 0.08920398603423488
# Epochh : 6800, Average Train Meta Loss : 0.11772871508223753, Average Test Meta Loss : 0.08790495567300335
# Epochh : 6900, Average Train Meta Loss : 0.11602644608199239, Average Test Meta Loss : 0.08663687027067452
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-58-65e0fb4a9f05> in <module>()
#      17     # Note that we need to sample the graph from the test data
#      18     graph = random.sample(GRAPH_TEST, 1)
# ---> 19     test_set_validation(model,new_model,graph[0],lr_k,k,store_test_loss_meta)
#      20
#      21     # Print losses every 'printing_step' epochs
#
# <ipython-input-56-ce3626fa0cf2> in test_set_validation(model, new_model, graph, lr_inner, k, store_test_loss_meta)
#      17 def test_set_validation(model,new_model,graph,lr_inner,k,store_test_loss_meta):
#      18     # This functions does not actually affect the main algorithm, it is just used to evaluate the new model
# ---> 19     new_model = training(model, graph, lr_inner, k)
#      20     # Obtain the loss
#      21     loss = evaluation(new_model, graph)
#
# <ipython-input-56-ce3626fa0cf2> in training(model, graph, lr_k, k)
#      76         koptimizer.zero_grad()
#      77         # Evaluate the model
# ---> 78         loss = evaluation(new_model, graph, item = False)
#      79         # Backpropagate
#      80         loss.backward()
#
# <ipython-input-56-ce3626fa0cf2> in evaluation(new_model, graph, item)
#      58 def evaluation(new_model, graph, item = True):
#      59     # Make model prediction
# ---> 60     prediction = new_model(graph.x,graph.edge_index,graph.batch)
#      61     # Get loss
#      62     if item == True: #Depending on whether we need to return the loss value for storing or for backprop
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-55-8db92c1776b0> in forward(self, input_x, edge_index, batch)
#      24         x = self.norm(x)
#      25         x = self.relu(x)
# ---> 26         x = self.hidden3(x,edge_index)
#      27         x = self.relu(x)
#      28
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch_geometric/nn/conv/graph_conv.py in forward(self, x, edge_index, edge_weight, size)
#      79         # propagate_type: (x: OptPairTensor, edge_weight: OptTensor)
#      80         out = self.propagate(edge_index, x=x, edge_weight=edge_weight,
# ---> 81                              size=size)
#      82         out = self.lin_rel(out)
#      83
#
# /usr/local/lib/python3.7/dist-packages/torch_geometric/nn/conv/message_passing.py in propagate(self, edge_index, size, **kwargs)
#     342                     if res is not None:
#     343                         aggr_kwargs = res[0] if isinstance(res, tuple) else res
# --> 344                 out = self.aggregate(out, **aggr_kwargs)
#     345                 for hook in self._aggregate_forward_hooks.values():
#     346                     res = hook(self, (aggr_kwargs, ), out)
#
# /usr/local/lib/python3.7/dist-packages/torch_geometric/nn/conv/message_passing.py in aggregate(self, inputs, index, ptr, dim_size)
#     426         else:
#     427             return scatter(inputs, index, dim=self.node_dim, dim_size=dim_size,
# --> 428                            reduce=self.aggr)
#     429
#     430     def message_and_aggregate(self, adj_t: SparseTensor) -> Tensor:
#
# /usr/local/lib/python3.7/dist-packages/torch_scatter/scatter.py in scatter(src, index, dim, out, dim_size, reduce)
#     150     """
#     151     if reduce == 'sum' or reduce == 'add':
# --> 152         return scatter_sum(src, index, dim, out, dim_size)
#     153     if reduce == 'mul':
#     154         return scatter_mul(src, index, dim, out, dim_size)
#
# /usr/local/lib/python3.7/dist-packages/torch_scatter/scatter.py in scatter_sum(src, index, dim, out, dim_size)
#       9                 out: Optional[torch.Tensor] = None,
#      10                 dim_size: Optional[int] = None) -> torch.Tensor:
# ---> 11     index = broadcast(index, src, dim)
#      12     if out is None:
#      13         size = list(src.size())
#
# /usr/local/lib/python3.7/dist-packages/torch_scatter/utils.py in broadcast(src, other, dim)
#      10     for _ in range(src.dim(), other.dim()):
#      11         src = src.unsqueeze(-1)
# ---> 12     src = src.expand_as(other)
#      13     return src
#
# KeyboardInterrupt:

# %% [markdown]
# <h1> Few Shot learning with new meta-model

# %% [markdown]
# The model performs good few shot learning

# %%
graph = GRAPH_TEST[0] 
k_shot_updates = 4
initialization_to_store_meta_losses()
for shots in range(k_shot_updates):
    new_model = training(model, graph, lr_k, shots)
    train_set_evaluation(new_model,graph,store_train_loss_meta) 

plt.plot(store_train_loss_meta,label = 'Loss')
plt.legend()
plt.xlabel('k shots')
# Out:
# Text(0.5, 0, 'k shots')

# %% [markdown]
# ## Second-Order MAML

# %%
'''
Handling computation graphs and second-order backprop help and partial inspiration from: 
- https://discuss.pytorch.org/t/how-to-save-computation-graph-of-a-gradient/128286/2 
- https://discuss.pytorch.org/t/when-do-i-use-create-graph-in-autograd-grad/32853/3 
- https://lucainiaoge.github.io/download/PyTorch-create_graph-is-true_Tutorial_and_Example.pdf
- https://www.youtube.com/watch?v=IkDw22a8BDE
- https://discuss.pytorch.org/t/how-to-manually-update-network-parameters-while-keeping-track-of-its-computational-graph/131642/2
- https://discuss.pytorch.org/t/how-to-calculate-2nd-derivative-of-a-likelihood-function/15085/3
- https://pytorch.org/tutorials/recipes/recipes/zeroing_out_gradients.html
- https://higher.readthedocs.io/en/latest/toplevel.html

Neural network configuration and helper class functions copied directly from 
-https://github.com/AdrienLE/ANIML/blob/master/ANIML.ipynb

Note, different ways to refer to the task-specific vs. meta/aggregate updates to the parameters
Sometimes called "inner" and "outer" loop, respectively
Here, refered to as "task_specific" and "agg"/meta" (the latter, for consistency w/ ocariz code)
'''


#Instantiate the model network
model = GNN()
# move to the current device (GPU or CPU)
# help from: https://stackoverflow.com/questions/46704352/porting-pytorch-code-from-cpu-to-gpu
model.to(device)

T = 25 # num tasks
N = 1 # number of inner loop steps (notation from: https://www.bayeswatch.com/2018/11/30/HTYM/)
num_samples = 10 # number of samples to draw from the task
lr_task_specific = 0.01 # task specific learning rate
lr_meta = 0.001 # meta-update learning rate
num_epochs = 10000#70001 #Number of iterations for outer loop
printing_step = 5000 # show log of loss every x epochs

#Used to store the validation losses
metaLosses = []
metaValLosses = []

#Meta-optimizer for the outer loop
meta_optimizer = torch.optim.Adam(model.parameters(), lr = lr_meta)

#Inner optimizer, we were doing this by hand previously
inner_loop_optimizer = torch.optim.SGD(model.parameters(), lr = lr_task_specific)

for epoch in range(num_epochs):
    # store loss over all tasks to then do a large meta-level update of initial params
    # idea/help from video: https://www.youtube.com/watch?v=IkDw22a8BDE
    meta_loss = None
    
    #Sample a new wave each time
    train_tasks = random.sample(GRAPH_TRAIN, T)#[SineWaveTask_multi() for _ in range(T)]
    
    #Loop through all of the tasks
    for i, T_i in enumerate(train_tasks): 
        held_out_task_specific_loss, _, _ = task_specific_train_and_eval(model, T_i, inner_loop_optimizer, N)
        if meta_loss is None: 
            meta_loss = held_out_task_specific_loss
        else:
            meta_loss += held_out_task_specific_loss
            
    meta_optimizer.zero_grad()
    meta_loss /= T
    meta_loss.backward()
    meta_optimizer.step()
    metaLosses.append(meta_loss.item())
    
    # validation 
    val_task = GRAPH_TEST[0] # our own addition -- can vary
    val_loss, _, _ = task_specific_train_and_eval(model, val_task, inner_loop_optimizer, N)
    metaValLosses.append(val_loss.item())
    
    if epoch % printing_step == 0:
        print("Iter = ", epoch, " Current Loss", np.mean(metaLosses), " Val Loss: ", np.mean(metaValLosses))
        # saving model help from: 
        # https://pytorch.org/tutorials/beginner/saving_loading_models.html
        torch.save(model.state_dict(), f"{domain_type}_maml_model.pt")
# Out:
# Iter =  0  Current Loss 118.50360107421875  Val Loss:  0.004462186247110367
# Iter =  5000  Current Loss 3.1881933921925354  Val Loss:  0.32712721032764003

# %%
GRAPH_TRAIN
# Out:
# [Data(x=[18, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_41622', z=[18]),
#  Data(x=[23, 11], edge_index=[2, 44], edge_attr=[44, 4], y=[1, 19], pos=[23, 3], idx=[1], name='gdb_100754', z=[23]),
#  Data(x=[20, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_111222', z=[20]),
#  Data(x=[17, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_51027', z=[17]),
#  Data(x=[19, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_14737', z=[19]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_88140', z=[19]),
#  Data(x=[20, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_117106', z=[20]),
#  Data(x=[16, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_78651', z=[16]),
#  Data(x=[27, 11], edge_index=[2, 52], edge_attr=[52, 4], y=[1, 19], pos=[27, 3], idx=[1], name='gdb_118574', z=[27]),
#  Data(x=[16, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_79948', z=[16]),
#  Data(x=[20, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_108407', z=[20]),
#  Data(x=[11, 11], edge_index=[2, 22], edge_attr=[22, 4], y=[1, 19], pos=[11, 3], idx=[1], name='gdb_1032', z=[11]),
#  Data(x=[11, 11], edge_index=[2, 22], edge_attr=[22, 4], y=[1, 19], pos=[11, 3], idx=[1], name='gdb_131924', z=[11]),
#  Data(x=[20, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_90472', z=[20]),
#  Data(x=[17, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_72782', z=[17]),
#  Data(x=[21, 11], edge_index=[2, 44], edge_attr=[44, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_74796', z=[21]),
#  Data(x=[15, 11], edge_index=[2, 28], edge_attr=[28, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_61741', z=[15]),
#  Data(x=[25, 11], edge_index=[2, 50], edge_attr=[50, 4], y=[1, 19], pos=[25, 3], idx=[1], name='gdb_59057', z=[25]),
#  Data(x=[17, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_33736', z=[17]),
#  Data(x=[14, 11], edge_index=[2, 28], edge_attr=[28, 4], y=[1, 19], pos=[14, 3], idx=[1], name='gdb_131601', z=[14]),
#  Data(x=[19, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_90855', z=[19]),
#  Data(x=[19, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_15364', z=[19]),
#  Data(x=[15, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_49473', z=[15]),
#  Data(x=[17, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_7247', z=[17]),
#  Data(x=[11, 11], edge_index=[2, 22], edge_attr=[22, 4], y=[1, 19], pos=[11, 3], idx=[1], name='gdb_130886', z=[11]),
#  Data(x=[16, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_12665', z=[16]),
#  Data(x=[22, 11], edge_index=[2, 46], edge_attr=[46, 4], y=[1, 19], pos=[22, 3], idx=[1], name='gdb_64373', z=[22]),
#  Data(x=[20, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_116117', z=[20]),
#  Data(x=[15, 11], edge_index=[2, 30], edge_attr=[30, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_13360', z=[15]),
#  Data(x=[23, 11], edge_index=[2, 46], edge_attr=[46, 4], y=[1, 19], pos=[23, 3], idx=[1], name='gdb_86940', z=[23]),
#  Data(x=[18, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_90304', z=[18]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_108427', z=[19]),
#  Data(x=[18, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_65628', z=[18]),
#  Data(x=[17, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_71453', z=[17]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_17139', z=[19]),
#  Data(x=[19, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_122696', z=[19]),
#  Data(x=[14, 11], edge_index=[2, 28], edge_attr=[28, 4], y=[1, 19], pos=[14, 3], idx=[1], name='gdb_27936', z=[14]),
#  Data(x=[22, 11], edge_index=[2, 46], edge_attr=[46, 4], y=[1, 19], pos=[22, 3], idx=[1], name='gdb_11038', z=[22]),
#  Data(x=[16, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_33899', z=[16]),
#  Data(x=[22, 11], edge_index=[2, 44], edge_attr=[44, 4], y=[1, 19], pos=[22, 3], idx=[1], name='gdb_22133', z=[22]),
#  Data(x=[19, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_100414', z=[19]),
#  Data(x=[14, 11], edge_index=[2, 28], edge_attr=[28, 4], y=[1, 19], pos=[14, 3], idx=[1], name='gdb_131957', z=[14]),
#  Data(x=[17, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_66905', z=[17]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_81872', z=[19]),
#  Data(x=[18, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_127132', z=[18]),
#  Data(x=[16, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_104570', z=[16]),
#  Data(x=[17, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_81895', z=[17]),
#  Data(x=[15, 11], edge_index=[2, 30], edge_attr=[30, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_85510', z=[15]),
#  Data(x=[17, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_16024', z=[17]),
#  Data(x=[17, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_8695', z=[17]),
#  Data(x=[19, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_39140', z=[19]),
#  Data(x=[19, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_17617', z=[19]),
#  Data(x=[19, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_93758', z=[19]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_28325', z=[19]),
#  Data(x=[14, 11], edge_index=[2, 26], edge_attr=[26, 4], y=[1, 19], pos=[14, 3], idx=[1], name='gdb_1209', z=[14]),
#  Data(x=[15, 11], edge_index=[2, 30], edge_attr=[30, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_125451', z=[15]),
#  Data(x=[14, 11], edge_index=[2, 26], edge_attr=[26, 4], y=[1, 19], pos=[14, 3], idx=[1], name='gdb_7039', z=[14]),
#  Data(x=[17, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_58395', z=[17]),
#  Data(x=[18, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_103532', z=[18]),
#  Data(x=[14, 11], edge_index=[2, 26], edge_attr=[26, 4], y=[1, 19], pos=[14, 3], idx=[1], name='gdb_10004', z=[14]),
#  Data(x=[17, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_38600', z=[17]),
#  Data(x=[16, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_43977', z=[16]),
#  Data(x=[23, 11], edge_index=[2, 48], edge_attr=[48, 4], y=[1, 19], pos=[23, 3], idx=[1], name='gdb_84852', z=[23]),
#  Data(x=[19, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_49075', z=[19]),
#  Data(x=[15, 11], edge_index=[2, 28], edge_attr=[28, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_1432', z=[15]),
#  Data(x=[17, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_10832', z=[17]),
#  Data(x=[22, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[22, 3], idx=[1], name='gdb_22115', z=[22]),
#  Data(x=[18, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_24129', z=[18]),
#  Data(x=[17, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_82189', z=[17]),
#  Data(x=[15, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_4195', z=[15]),
#  Data(x=[17, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_14520', z=[17]),
#  Data(x=[17, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_40089', z=[17]),
#  Data(x=[20, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_116073', z=[20]),
#  Data(x=[18, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_93070', z=[18]),
#  Data(x=[21, 11], edge_index=[2, 44], edge_attr=[44, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_77467', z=[21]),
#  Data(x=[21, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_56192', z=[21]),
#  Data(x=[18, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_37482', z=[18]),
#  Data(x=[17, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_34532', z=[17]),
#  Data(x=[18, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_98635', z=[18]),
#  Data(x=[19, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_63593', z=[19]),
#  Data(x=[19, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_102272', z=[19]),
#  Data(x=[18, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_46737', z=[18]),
#  Data(x=[18, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_109639', z=[18]),
#  Data(x=[17, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_123840', z=[17]),
#  Data(x=[17, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_16828', z=[17]),
#  Data(x=[11, 11], edge_index=[2, 22], edge_attr=[22, 4], y=[1, 19], pos=[11, 3], idx=[1], name='gdb_21622', z=[11]),
#  Data(x=[19, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_86101', z=[19]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_46513', z=[19]),
#  Data(x=[18, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_84508', z=[18]),
#  Data(x=[18, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_81570', z=[18]),
#  Data(x=[21, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_120621', z=[21]),
#  Data(x=[21, 11], edge_index=[2, 44], edge_attr=[44, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_91904', z=[21]),
#  Data(x=[18, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_47041', z=[18]),
#  Data(x=[22, 11], edge_index=[2, 44], edge_attr=[44, 4], y=[1, 19], pos=[22, 3], idx=[1], name='gdb_121170', z=[22]),
#  Data(x=[18, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_53938', z=[18]),
#  Data(x=[23, 11], edge_index=[2, 50], edge_attr=[50, 4], y=[1, 19], pos=[23, 3], idx=[1], name='gdb_68596', z=[23]),
#  Data(x=[18, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_12859', z=[18]),
#  Data(x=[17, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_28603', z=[17]),
#  Data(x=[15, 11], edge_index=[2, 30], edge_attr=[30, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_2310', z=[15]),
#  Data(x=[15, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_48568', z=[15]),
#  Data(x=[22, 11], edge_index=[2, 44], edge_attr=[44, 4], y=[1, 19], pos=[22, 3], idx=[1], name='gdb_13136', z=[22]),
#  Data(x=[18, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_47310', z=[18]),
#  Data(x=[21, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_54209', z=[21]),
#  Data(x=[19, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_108121', z=[19]),
#  Data(x=[13, 11], edge_index=[2, 26], edge_attr=[26, 4], y=[1, 19], pos=[13, 3], idx=[1], name='gdb_20330', z=[13]),
#  Data(x=[16, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_129870', z=[16]),
#  Data(x=[22, 11], edge_index=[2, 44], edge_attr=[44, 4], y=[1, 19], pos=[22, 3], idx=[1], name='gdb_115746', z=[22]),
#  Data(x=[15, 11], edge_index=[2, 30], edge_attr=[30, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_28969', z=[15]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_68173', z=[19]),
#  Data(x=[17, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_38743', z=[17]),
#  Data(x=[21, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_57204', z=[21]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_63727', z=[19]),
#  Data(x=[19, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_72710', z=[19]),
#  Data(x=[15, 11], edge_index=[2, 30], edge_attr=[30, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_77211', z=[15]),
#  Data(x=[21, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_58319', z=[21]),
#  Data(x=[16, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_66301', z=[16]),
#  Data(x=[16, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_19617', z=[16]),
#  Data(x=[15, 11], edge_index=[2, 30], edge_attr=[30, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_2586', z=[15]),
#  Data(x=[17, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_75770', z=[17]),
#  Data(x=[17, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_53425', z=[17]),
#  Data(x=[16, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_12318', z=[16]),
#  Data(x=[13, 11], edge_index=[2, 26], edge_attr=[26, 4], y=[1, 19], pos=[13, 3], idx=[1], name='gdb_7874', z=[13]),
#  Data(x=[16, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_25916', z=[16]),
#  Data(x=[18, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_36746', z=[18]),
#  Data(x=[17, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_76160', z=[17]),
#  Data(x=[22, 11], edge_index=[2, 46], edge_attr=[46, 4], y=[1, 19], pos=[22, 3], idx=[1], name='gdb_66153', z=[22]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_35079', z=[19]),
#  Data(x=[22, 11], edge_index=[2, 46], edge_attr=[46, 4], y=[1, 19], pos=[22, 3], idx=[1], name='gdb_113228', z=[22]),
#  Data(x=[15, 11], edge_index=[2, 30], edge_attr=[30, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_28071', z=[15]),
#  Data(x=[17, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_14202', z=[17]),
#  Data(x=[13, 11], edge_index=[2, 24], edge_attr=[24, 4], y=[1, 19], pos=[13, 3], idx=[1], name='gdb_1500', z=[13]),
#  Data(x=[14, 11], edge_index=[2, 30], edge_attr=[30, 4], y=[1, 19], pos=[14, 3], idx=[1], name='gdb_50025', z=[14]),
#  Data(x=[11, 11], edge_index=[2, 22], edge_attr=[22, 4], y=[1, 19], pos=[11, 3], idx=[1], name='gdb_21827', z=[11]),
#  Data(x=[21, 11], edge_index=[2, 44], edge_attr=[44, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_80446', z=[21]),
#  Data(x=[16, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_45536', z=[16]),
#  Data(x=[13, 11], edge_index=[2, 26], edge_attr=[26, 4], y=[1, 19], pos=[13, 3], idx=[1], name='gdb_5417', z=[13]),
#  Data(x=[16, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_54126', z=[16]),
#  Data(x=[20, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_101411', z=[20]),
#  Data(x=[16, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_123367', z=[16]),
#  Data(x=[17, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_29279', z=[17]),
#  Data(x=[19, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_93080', z=[19]),
#  Data(x=[17, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_12982', z=[17]),
#  Data(x=[21, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_85673', z=[21]),
#  Data(x=[23, 11], edge_index=[2, 46], edge_attr=[46, 4], y=[1, 19], pos=[23, 3], idx=[1], name='gdb_86316', z=[23]),
#  Data(x=[20, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_94104', z=[20]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_47743', z=[19]),
#  Data(x=[14, 11], edge_index=[2, 28], edge_attr=[28, 4], y=[1, 19], pos=[14, 3], idx=[1], name='gdb_48108', z=[14]),
#  Data(x=[21, 11], edge_index=[2, 44], edge_attr=[44, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_94575', z=[21]),
#  Data(x=[14, 11], edge_index=[2, 28], edge_attr=[28, 4], y=[1, 19], pos=[14, 3], idx=[1], name='gdb_129580', z=[14]),
#  Data(x=[21, 11], edge_index=[2, 44], edge_attr=[44, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_115858', z=[21]),
#  Data(x=[15, 11], edge_index=[2, 30], edge_attr=[30, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_29938', z=[15]),
#  Data(x=[21, 11], edge_index=[2, 44], edge_attr=[44, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_36444', z=[21]),
#  Data(x=[18, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_7485', z=[18]),
#  Data(x=[21, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_122647', z=[21]),
#  Data(x=[21, 11], edge_index=[2, 44], edge_attr=[44, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_121276', z=[21]),
#  Data(x=[21, 11], edge_index=[2, 44], edge_attr=[44, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_70142', z=[21]),
#  Data(x=[20, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_106508', z=[20]),
#  Data(x=[24, 11], edge_index=[2, 46], edge_attr=[46, 4], y=[1, 19], pos=[24, 3], idx=[1], name='gdb_100723', z=[24]),
#  Data(x=[16, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_128061', z=[16]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_62898', z=[19]),
#  Data(x=[18, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_98331', z=[18]),
#  Data(x=[15, 11], edge_index=[2, 30], edge_attr=[30, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_13842', z=[15]),
#  Data(x=[21, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_57968', z=[21]),
#  Data(x=[20, 11], edge_index=[2, 44], edge_attr=[44, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_70021', z=[20]),
#  Data(x=[20, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_115211', z=[20]),
#  Data(x=[15, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_48391', z=[15]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_47589', z=[19]),
#  Data(x=[17, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_14847', z=[17]),
#  Data(x=[20, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_75057', z=[20]),
#  Data(x=[13, 11], edge_index=[2, 28], edge_attr=[28, 4], y=[1, 19], pos=[13, 3], idx=[1], name='gdb_130748', z=[13]),
#  Data(x=[20, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_121336', z=[20]),
#  Data(x=[18, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_127064', z=[18]),
#  Data(x=[18, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_8506', z=[18]),
#  Data(x=[20, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_122792', z=[20]),
#  Data(x=[12, 11], edge_index=[2, 24], edge_attr=[24, 4], y=[1, 19], pos=[12, 3], idx=[1], name='gdb_48379', z=[12]),
#  Data(x=[21, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_58239', z=[21]),
#  Data(x=[25, 11], edge_index=[2, 50], edge_attr=[50, 4], y=[1, 19], pos=[25, 3], idx=[1], name='gdb_57395', z=[25]),
#  Data(x=[21, 11], edge_index=[2, 44], edge_attr=[44, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_95308', z=[21]),
#  Data(x=[18, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_110483', z=[18]),
#  Data(x=[23, 11], edge_index=[2, 44], edge_attr=[44, 4], y=[1, 19], pos=[23, 3], idx=[1], name='gdb_121802', z=[23]),
#  Data(x=[14, 11], edge_index=[2, 28], edge_attr=[28, 4], y=[1, 19], pos=[14, 3], idx=[1], name='gdb_132383', z=[14]),
#  Data(x=[23, 11], edge_index=[2, 46], edge_attr=[46, 4], y=[1, 19], pos=[23, 3], idx=[1], name='gdb_57426', z=[23]),
#  Data(x=[15, 11], edge_index=[2, 30], edge_attr=[30, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_33579', z=[15]),
#  Data(x=[20, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_113766', z=[20]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_24727', z=[19]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_112006', z=[19]),
#  Data(x=[17, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_16437', z=[17]),
#  Data(x=[18, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_119310', z=[18]),
#  Data(x=[20, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_68543', z=[20]),
#  Data(x=[22, 11], edge_index=[2, 48], edge_attr=[48, 4], y=[1, 19], pos=[22, 3], idx=[1], name='gdb_105803', z=[22]),
#  Data(x=[18, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_126309', z=[18]),
#  Data(x=[16, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_133770', z=[16]),
#  Data(x=[12, 11], edge_index=[2, 24], edge_attr=[24, 4], y=[1, 19], pos=[12, 3], idx=[1], name='gdb_21589', z=[12]),
#  Data(x=[17, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_2015', z=[17]),
#  Data(x=[17, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_91217', z=[17]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_18297', z=[19]),
#  Data(x=[16, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_82267', z=[16]),
#  Data(x=[18, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_51260', z=[18]),
#  Data(x=[21, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_73873', z=[21]),
#  Data(x=[16, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_44416', z=[16]),
#  Data(x=[19, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_31009', z=[19]),
#  Data(x=[11, 11], edge_index=[2, 22], edge_attr=[22, 4], y=[1, 19], pos=[11, 3], idx=[1], name='gdb_130828', z=[11]),
#  Data(x=[17, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_108301', z=[17]),
#  Data(x=[21, 11], edge_index=[2, 46], edge_attr=[46, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_91953', z=[21]),
#  Data(x=[18, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_74856', z=[18]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_13987', z=[19]),
#  Data(x=[19, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_66358', z=[19]),
#  Data(x=[17, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_30876', z=[17]),
#  Data(x=[21, 11], edge_index=[2, 44], edge_attr=[44, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_119170', z=[21]),
#  Data(x=[14, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[14, 3], idx=[1], name='gdb_34510', z=[14]),
#  Data(x=[19, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_110034', z=[19]),
#  Data(x=[18, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_67483', z=[18]),
#  Data(x=[19, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_41197', z=[19]),
#  Data(x=[14, 11], edge_index=[2, 28], edge_attr=[28, 4], y=[1, 19], pos=[14, 3], idx=[1], name='gdb_133269', z=[14]),
#  Data(x=[14, 11], edge_index=[2, 28], edge_attr=[28, 4], y=[1, 19], pos=[14, 3], idx=[1], name='gdb_4478', z=[14]),
#  Data(x=[16, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_85697', z=[16]),
#  Data(x=[18, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_86167', z=[18]),
#  Data(x=[13, 11], edge_index=[2, 26], edge_attr=[26, 4], y=[1, 19], pos=[13, 3], idx=[1], name='gdb_129141', z=[13]),
#  Data(x=[18, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_10976', z=[18]),
#  Data(x=[19, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_82766', z=[19]),
#  Data(x=[23, 11], edge_index=[2, 48], edge_attr=[48, 4], y=[1, 19], pos=[23, 3], idx=[1], name='gdb_114363', z=[23]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_107527', z=[19]),
#  Data(x=[12, 11], edge_index=[2, 24], edge_attr=[24, 4], y=[1, 19], pos=[12, 3], idx=[1], name='gdb_2566', z=[12]),
#  Data(x=[22, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[22, 3], idx=[1], name='gdb_102513', z=[22]),
#  Data(x=[21, 11], edge_index=[2, 46], edge_attr=[46, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_107729', z=[21]),
#  Data(x=[21, 11], edge_index=[2, 46], edge_attr=[46, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_106160', z=[21]),
#  Data(x=[7, 11], edge_index=[2, 12], edge_attr=[12, 4], y=[1, 19], pos=[7, 3], idx=[1], name='gdb_491', z=[7]),
#  Data(x=[17, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_43312', z=[17]),
#  Data(x=[23, 11], edge_index=[2, 48], edge_attr=[48, 4], y=[1, 19], pos=[23, 3], idx=[1], name='gdb_115788', z=[23]),
#  Data(x=[22, 11], edge_index=[2, 44], edge_attr=[44, 4], y=[1, 19], pos=[22, 3], idx=[1], name='gdb_12533', z=[22]),
#  Data(x=[14, 11], edge_index=[2, 28], edge_attr=[28, 4], y=[1, 19], pos=[14, 3], idx=[1], name='gdb_27134', z=[14]),
#  Data(x=[17, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_77015', z=[17]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_94785', z=[19]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_91302', z=[19]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_89722', z=[19]),
#  Data(x=[13, 11], edge_index=[2, 26], edge_attr=[26, 4], y=[1, 19], pos=[13, 3], idx=[1], name='gdb_43656', z=[13]),
#  Data(x=[20, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_6139', z=[20]),
#  Data(x=[21, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_62015', z=[21]),
#  Data(x=[20, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_8682', z=[20]),
#  Data(x=[17, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_18302', z=[17]),
#  Data(x=[17, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_1251', z=[17]),
#  Data(x=[18, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_32876', z=[18]),
#  Data(x=[22, 11], edge_index=[2, 46], edge_attr=[46, 4], y=[1, 19], pos=[22, 3], idx=[1], name='gdb_58839', z=[22]),
#  Data(x=[21, 11], edge_index=[2, 46], edge_attr=[46, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_107871', z=[21]),
#  Data(x=[20, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_78195', z=[20]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_95379', z=[19]),
#  Data(x=[16, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_35537', z=[16]),
#  Data(x=[20, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_31024', z=[20]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_110246', z=[19]),
#  Data(x=[17, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_99016', z=[17]),
#  Data(x=[16, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_105571', z=[16]),
#  Data(x=[15, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_45629', z=[15]),
#  Data(x=[15, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_37125', z=[15]),
#  Data(x=[18, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_83805', z=[18]),
#  Data(x=[16, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_125069', z=[16]),
#  Data(x=[18, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_108161', z=[18]),
#  Data(x=[18, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_44943', z=[18]),
#  Data(x=[21, 11], edge_index=[2, 46], edge_attr=[46, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_82616', z=[21]),
#  Data(x=[18, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_23471', z=[18]),
#  Data(x=[20, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_22994', z=[20]),
#  Data(x=[18, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_113621', z=[18]),
#  Data(x=[16, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_45960', z=[16]),
#  Data(x=[19, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_105393', z=[19]),
#  Data(x=[16, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_67750', z=[16]),
#  Data(x=[21, 11], edge_index=[2, 44], edge_attr=[44, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_90414', z=[21]),
#  Data(x=[18, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_93207', z=[18]),
#  Data(x=[24, 11], edge_index=[2, 48], edge_attr=[48, 4], y=[1, 19], pos=[24, 3], idx=[1], name='gdb_99772', z=[24]),
#  Data(x=[16, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_34181', z=[16]),
#  Data(x=[14, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[14, 3], idx=[1], name='gdb_11659', z=[14]),
#  Data(x=[19, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_73803', z=[19]),
#  Data(x=[16, 11], edge_index=[2, 30], edge_attr=[30, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_102071', z=[16]),
#  Data(x=[16, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_45466', z=[16]),
#  Data(x=[23, 11], edge_index=[2, 46], edge_attr=[46, 4], y=[1, 19], pos=[23, 3], idx=[1], name='gdb_118099', z=[23]),
#  Data(x=[17, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_88358', z=[17]),
#  Data(x=[17, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_132351', z=[17]),
#  Data(x=[19, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_76313', z=[19]),
#  Data(x=[17, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_34076', z=[17]),
#  Data(x=[15, 11], edge_index=[2, 28], edge_attr=[28, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_1153', z=[15]),
#  Data(x=[15, 11], edge_index=[2, 30], edge_attr=[30, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_84192', z=[15]),
#  Data(x=[17, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_111487', z=[17]),
#  Data(x=[20, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_124458', z=[20]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_75716', z=[19]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_50260', z=[19]),
#  Data(x=[14, 11], edge_index=[2, 26], edge_attr=[26, 4], y=[1, 19], pos=[14, 3], idx=[1], name='gdb_50805', z=[14]),
#  Data(x=[17, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_43380', z=[17]),
#  Data(x=[21, 11], edge_index=[2, 44], edge_attr=[44, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_38373', z=[21]),
#  Data(x=[19, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_90127', z=[19]),
#  Data(x=[15, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_3475', z=[15]),
#  Data(x=[18, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_14200', z=[18]),
#  Data(x=[16, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_43120', z=[16]),
#  Data(x=[16, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_6595', z=[16]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_65398', z=[19]),
#  Data(x=[20, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_86124', z=[20]),
#  Data(x=[20, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_10615', z=[20]),
#  Data(x=[14, 11], edge_index=[2, 28], edge_attr=[28, 4], y=[1, 19], pos=[14, 3], idx=[1], name='gdb_9448', z=[14]),
#  Data(x=[15, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_44375', z=[15]),
#  Data(x=[20, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_17351', z=[20]),
#  Data(x=[14, 11], edge_index=[2, 28], edge_attr=[28, 4], y=[1, 19], pos=[14, 3], idx=[1], name='gdb_130252', z=[14]),
#  Data(x=[17, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_17572', z=[17]),
#  Data(x=[14, 11], edge_index=[2, 26], edge_attr=[26, 4], y=[1, 19], pos=[14, 3], idx=[1], name='gdb_8779', z=[14]),
#  Data(x=[17, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_46669', z=[17]),
#  Data(x=[25, 11], edge_index=[2, 50], edge_attr=[50, 4], y=[1, 19], pos=[25, 3], idx=[1], name='gdb_118151', z=[25]),
#  Data(x=[20, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_62910', z=[20]),
#  Data(x=[17, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_68576', z=[17]),
#  Data(x=[17, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_24599', z=[17]),
#  Data(x=[17, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_95727', z=[17]),
#  Data(x=[19, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_38670', z=[19]),
#  Data(x=[19, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_67684', z=[19]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_47818', z=[19]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_73935', z=[19]),
#  Data(x=[23, 11], edge_index=[2, 46], edge_attr=[46, 4], y=[1, 19], pos=[23, 3], idx=[1], name='gdb_58112', z=[23]),
#  Data(x=[16, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_16653', z=[16]),
#  Data(x=[18, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_89942', z=[18]),
#  Data(x=[16, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_69341', z=[16]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_69436', z=[19]),
#  Data(x=[22, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[22, 3], idx=[1], name='gdb_7202', z=[22]),
#  Data(x=[21, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_113099', z=[21]),
#  Data(x=[25, 11], edge_index=[2, 52], edge_attr=[52, 4], y=[1, 19], pos=[25, 3], idx=[1], name='gdb_59664', z=[25]),
#  Data(x=[20, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_119225', z=[20]),
#  Data(x=[14, 11], edge_index=[2, 30], edge_attr=[30, 4], y=[1, 19], pos=[14, 3], idx=[1], name='gdb_5681', z=[14]),
#  Data(x=[15, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_48920', z=[15]),
#  Data(x=[19, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_56228', z=[19]),
#  Data(x=[9, 11], edge_index=[2, 16], edge_attr=[16, 4], y=[1, 19], pos=[9, 3], idx=[1], name='gdb_1367', z=[9]),
#  Data(x=[18, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_18881', z=[18]),
#  Data(x=[19, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_72432', z=[19]),
#  Data(x=[21, 11], edge_index=[2, 46], edge_attr=[46, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_62704', z=[21]),
#  Data(x=[18, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_117909', z=[18]),
#  Data(x=[20, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_126536', z=[20]),
#  Data(x=[20, 11], edge_index=[2, 44], edge_attr=[44, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_79360', z=[20]),
#  Data(x=[15, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_18329', z=[15]),
#  Data(x=[16, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_130711', z=[16]),
#  Data(x=[20, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_12105', z=[20]),
#  Data(x=[19, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_17553', z=[19]),
#  Data(x=[14, 11], edge_index=[2, 28], edge_attr=[28, 4], y=[1, 19], pos=[14, 3], idx=[1], name='gdb_127905', z=[14]),
#  Data(x=[22, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[22, 3], idx=[1], name='gdb_5818', z=[22]),
#  Data(x=[16, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_35702', z=[16]),
#  Data(x=[19, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_90872', z=[19]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_51562', z=[19]),
#  Data(x=[21, 11], edge_index=[2, 48], edge_attr=[48, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_72193', z=[21]),
#  Data(x=[14, 11], edge_index=[2, 28], edge_attr=[28, 4], y=[1, 19], pos=[14, 3], idx=[1], name='gdb_27823', z=[14]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_63558', z=[19]),
#  Data(x=[18, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_50527', z=[18]),
#  Data(x=[17, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_35321', z=[17]),
#  Data(x=[17, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_74781', z=[17]),
#  Data(x=[15, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_79621', z=[15]),
#  Data(x=[20, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_112007', z=[20]),
#  Data(x=[21, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_123213', z=[21]),
#  Data(x=[19, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_4070', z=[19]),
#  Data(x=[18, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_116431', z=[18]),
#  Data(x=[21, 11], edge_index=[2, 48], edge_attr=[48, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_110472', z=[21]),
#  Data(x=[20, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_108689', z=[20]),
#  Data(x=[20, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_119200', z=[20]),
#  Data(x=[13, 11], edge_index=[2, 28], edge_attr=[28, 4], y=[1, 19], pos=[13, 3], idx=[1], name='gdb_5778', z=[13]),
#  Data(x=[15, 11], edge_index=[2, 30], edge_attr=[30, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_23108', z=[15]),
#  Data(x=[17, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_84261', z=[17]),
#  Data(x=[18, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_64111', z=[18]),
#  Data(x=[18, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_120243', z=[18]),
#  Data(x=[14, 11], edge_index=[2, 28], edge_attr=[28, 4], y=[1, 19], pos=[14, 3], idx=[1], name='gdb_132617', z=[14]),
#  Data(x=[17, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_113024', z=[17]),
#  Data(x=[16, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_27816', z=[16]),
#  Data(x=[14, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[14, 3], idx=[1], name='gdb_18821', z=[14]),
#  Data(x=[23, 11], edge_index=[2, 50], edge_attr=[50, 4], y=[1, 19], pos=[23, 3], idx=[1], name='gdb_40000', z=[23]),
#  Data(x=[18, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_62150', z=[18]),
#  Data(x=[20, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_119286', z=[20]),
#  Data(x=[19, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_103133', z=[19]),
#  Data(x=[22, 11], edge_index=[2, 48], edge_attr=[48, 4], y=[1, 19], pos=[22, 3], idx=[1], name='gdb_70903', z=[22]),
#  Data(x=[22, 11], edge_index=[2, 48], edge_attr=[48, 4], y=[1, 19], pos=[22, 3], idx=[1], name='gdb_89253', z=[22]),
#  Data(x=[11, 11], edge_index=[2, 20], edge_attr=[20, 4], y=[1, 19], pos=[11, 3], idx=[1], name='gdb_42380', z=[11]),
#  Data(x=[18, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_40805', z=[18]),
#  Data(x=[15, 11], edge_index=[2, 30], edge_attr=[30, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_27000', z=[15]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_76220', z=[19]),
#  Data(x=[13, 11], edge_index=[2, 30], edge_attr=[30, 4], y=[1, 19], pos=[13, 3], idx=[1], name='gdb_2003', z=[13]),
#  Data(x=[19, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_31710', z=[19]),
#  Data(x=[17, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_127298', z=[17]),
#  Data(x=[23, 11], edge_index=[2, 48], edge_attr=[48, 4], y=[1, 19], pos=[23, 3], idx=[1], name='gdb_122299', z=[23]),
#  Data(x=[13, 11], edge_index=[2, 26], edge_attr=[26, 4], y=[1, 19], pos=[13, 3], idx=[1], name='gdb_133456', z=[13]),
#  Data(x=[16, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_32128', z=[16]),
#  Data(x=[12, 11], edge_index=[2, 24], edge_attr=[24, 4], y=[1, 19], pos=[12, 3], idx=[1], name='gdb_129534', z=[12]),
#  Data(x=[16, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_70982', z=[16]),
#  Data(x=[18, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_39947', z=[18]),
#  Data(x=[21, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_13628', z=[21]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_84500', z=[19]),
#  Data(x=[17, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_37183', z=[17]),
#  Data(x=[22, 11], edge_index=[2, 46], edge_attr=[46, 4], y=[1, 19], pos=[22, 3], idx=[1], name='gdb_119458', z=[22]),
#  Data(x=[14, 11], edge_index=[2, 28], edge_attr=[28, 4], y=[1, 19], pos=[14, 3], idx=[1], name='gdb_132612', z=[14]),
#  Data(x=[23, 11], edge_index=[2, 44], edge_attr=[44, 4], y=[1, 19], pos=[23, 3], idx=[1], name='gdb_100086', z=[23]),
#  Data(x=[14, 11], edge_index=[2, 28], edge_attr=[28, 4], y=[1, 19], pos=[14, 3], idx=[1], name='gdb_23736', z=[14]),
#  Data(x=[18, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_90789', z=[18]),
#  Data(x=[18, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_39874', z=[18]),
#  Data(x=[21, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_122498', z=[21]),
#  Data(x=[19, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_81550', z=[19]),
#  Data(x=[20, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_32748', z=[20]),
#  Data(x=[13, 11], edge_index=[2, 30], edge_attr=[30, 4], y=[1, 19], pos=[13, 3], idx=[1], name='gdb_3544', z=[13]),
#  Data(x=[18, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_85992', z=[18]),
#  Data(x=[20, 11], edge_index=[2, 44], edge_attr=[44, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_78270', z=[20]),
#  Data(x=[17, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_41009', z=[17]),
#  Data(x=[15, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_10891', z=[15]),
#  Data(x=[18, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_39077', z=[18]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_114228', z=[19]),
#  Data(x=[18, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_30736', z=[18]),
#  Data(x=[16, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_37666', z=[16]),
#  Data(x=[16, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_13674', z=[16]),
#  Data(x=[17, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_86095', z=[17]),
#  Data(x=[20, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_54831', z=[20]),
#  Data(x=[19, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_73792', z=[19]),
#  Data(x=[16, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_55038', z=[16]),
#  Data(x=[19, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_121521', z=[19]),
#  Data(x=[15, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_28335', z=[15]),
#  Data(x=[17, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_53200', z=[17]),
# ...
#  Data(x=[18, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_68532', z=[18]),
#  Data(x=[15, 11], edge_index=[2, 30], edge_attr=[30, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_123373', z=[15]),
#  Data(x=[17, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_68733', z=[17]),
#  Data(x=[20, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_61566', z=[20]),
#  Data(x=[21, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_59506', z=[21]),
#  Data(x=[19, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_59315', z=[19]),
#  Data(x=[23, 11], edge_index=[2, 44], edge_attr=[44, 4], y=[1, 19], pos=[23, 3], idx=[1], name='gdb_122134', z=[23]),
#  Data(x=[21, 11], edge_index=[2, 46], edge_attr=[46, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_80619', z=[21]),
#  Data(x=[25, 11], edge_index=[2, 50], edge_attr=[50, 4], y=[1, 19], pos=[25, 3], idx=[1], name='gdb_100996', z=[25]),
#  Data(x=[16, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_43821', z=[16]),
#  Data(x=[16, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_67918', z=[16]),
#  Data(x=[18, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_127258', z=[18]),
#  Data(x=[17, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_124107', z=[17]),
#  Data(x=[15, 11], edge_index=[2, 28], edge_attr=[28, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_9241', z=[15]),
#  Data(x=[17, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_126772', z=[17]),
#  Data(x=[17, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_61137', z=[17]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_47517', z=[19]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_110267', z=[19]),
#  Data(x=[16, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_115089', z=[16]),
#  Data(x=[15, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_20118', z=[15]),
#  Data(x=[16, 11], edge_index=[2, 30], edge_attr=[30, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_98012', z=[16]),
#  Data(x=[23, 11], edge_index=[2, 48], edge_attr=[48, 4], y=[1, 19], pos=[23, 3], idx=[1], name='gdb_105239', z=[23]),
#  Data(x=[21, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_84088', z=[21]),
#  Data(x=[16, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_15176', z=[16]),
#  Data(x=[21, 11], edge_index=[2, 46], edge_attr=[46, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_106117', z=[21]),
#  Data(x=[16, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_94480', z=[16]),
#  Data(x=[16, 11], edge_index=[2, 30], edge_attr=[30, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_102429', z=[16]),
#  Data(x=[17, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_24124', z=[17]),
#  Data(x=[22, 11], edge_index=[2, 46], edge_attr=[46, 4], y=[1, 19], pos=[22, 3], idx=[1], name='gdb_111679', z=[22]),
#  Data(x=[21, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_103149', z=[21]),
#  Data(x=[21, 11], edge_index=[2, 44], edge_attr=[44, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_89657', z=[21]),
#  Data(x=[18, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_81198', z=[18]),
#  Data(x=[17, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_83414', z=[17]),
#  Data(x=[18, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_77281', z=[18]),
#  Data(x=[18, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_88749', z=[18]),
#  Data(x=[22, 11], edge_index=[2, 44], edge_attr=[44, 4], y=[1, 19], pos=[22, 3], idx=[1], name='gdb_102580', z=[22]),
#  Data(x=[20, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_11753', z=[20]),
#  Data(x=[17, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_116100', z=[17]),
#  Data(x=[15, 11], edge_index=[2, 30], edge_attr=[30, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_94137', z=[15]),
#  Data(x=[13, 11], edge_index=[2, 26], edge_attr=[26, 4], y=[1, 19], pos=[13, 3], idx=[1], name='gdb_2570', z=[13]),
#  Data(x=[23, 11], edge_index=[2, 50], edge_attr=[50, 4], y=[1, 19], pos=[23, 3], idx=[1], name='gdb_87485', z=[23]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_103291', z=[19]),
#  Data(x=[17, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_84460', z=[17]),
#  Data(x=[16, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_34727', z=[16]),
#  Data(x=[14, 11], edge_index=[2, 28], edge_attr=[28, 4], y=[1, 19], pos=[14, 3], idx=[1], name='gdb_84983', z=[14]),
#  Data(x=[17, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_69916', z=[17]),
#  Data(x=[23, 11], edge_index=[2, 44], edge_attr=[44, 4], y=[1, 19], pos=[23, 3], idx=[1], name='gdb_100652', z=[23]),
#  Data(x=[12, 11], edge_index=[2, 24], edge_attr=[24, 4], y=[1, 19], pos=[12, 3], idx=[1], name='gdb_23784', z=[12]),
#  Data(x=[19, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_54026', z=[19]),
#  Data(x=[18, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_77595', z=[18]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_85130', z=[19]),
#  Data(x=[15, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_72844', z=[15]),
#  Data(x=[15, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_24467', z=[15]),
#  Data(x=[20, 11], edge_index=[2, 46], edge_attr=[46, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_78926', z=[20]),
#  Data(x=[18, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_89209', z=[18]),
#  Data(x=[12, 11], edge_index=[2, 24], edge_attr=[24, 4], y=[1, 19], pos=[12, 3], idx=[1], name='gdb_131987', z=[12]),
#  Data(x=[20, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_62136', z=[20]),
#  Data(x=[17, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_93443', z=[17]),
#  Data(x=[17, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_47350', z=[17]),
#  Data(x=[20, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_60930', z=[20]),
#  Data(x=[12, 11], edge_index=[2, 26], edge_attr=[26, 4], y=[1, 19], pos=[12, 3], idx=[1], name='gdb_130504', z=[12]),
#  Data(x=[19, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_15445', z=[19]),
#  Data(x=[25, 11], edge_index=[2, 52], edge_attr=[52, 4], y=[1, 19], pos=[25, 3], idx=[1], name='gdb_80542', z=[25]),
#  Data(x=[19, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_33075', z=[19]),
#  Data(x=[22, 11], edge_index=[2, 44], edge_attr=[44, 4], y=[1, 19], pos=[22, 3], idx=[1], name='gdb_66163', z=[22]),
#  Data(x=[19, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_89429', z=[19]),
#  Data(x=[18, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_50339', z=[18]),
#  Data(x=[16, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_71278', z=[16]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_42008', z=[19]),
#  Data(x=[17, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_22278', z=[17]),
#  Data(x=[20, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_11410', z=[20]),
#  Data(x=[20, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_61830', z=[20]),
#  Data(x=[19, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_92923', z=[19]),
#  Data(x=[20, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_116020', z=[20]),
#  Data(x=[20, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_13886', z=[20]),
#  Data(x=[16, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_130087', z=[16]),
#  Data(x=[23, 11], edge_index=[2, 48], edge_attr=[48, 4], y=[1, 19], pos=[23, 3], idx=[1], name='gdb_80614', z=[23]),
#  Data(x=[21, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_119250', z=[21]),
#  Data(x=[17, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_48885', z=[17]),
#  Data(x=[18, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_87376', z=[18]),
#  Data(x=[17, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_45202', z=[17]),
#  Data(x=[15, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_124100', z=[15]),
#  Data(x=[18, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_18357', z=[18]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_89865', z=[19]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_68166', z=[19]),
#  Data(x=[17, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_69364', z=[17]),
#  Data(x=[17, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_6669', z=[17]),
#  Data(x=[21, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_85945', z=[21]),
#  Data(x=[15, 11], edge_index=[2, 28], edge_attr=[28, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_7228', z=[15]),
#  Data(x=[18, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_63329', z=[18]),
#  Data(x=[23, 11], edge_index=[2, 48], edge_attr=[48, 4], y=[1, 19], pos=[23, 3], idx=[1], name='gdb_70606', z=[23]),
#  Data(x=[16, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_49705', z=[16]),
#  Data(x=[14, 11], edge_index=[2, 28], edge_attr=[28, 4], y=[1, 19], pos=[14, 3], idx=[1], name='gdb_128910', z=[14]),
#  Data(x=[15, 11], edge_index=[2, 30], edge_attr=[30, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_2906', z=[15]),
#  Data(x=[20, 11], edge_index=[2, 44], edge_attr=[44, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_114463', z=[20]),
#  Data(x=[15, 11], edge_index=[2, 28], edge_attr=[28, 4], y=[1, 19], pos=[15, 3], idx=[1], name='gdb_1623', z=[15]),
#  Data(x=[17, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_98953', z=[17]),
#  Data(x=[18, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_47577', z=[18]),
#  Data(x=[16, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_54505', z=[16]),
#  Data(x=[23, 11], edge_index=[2, 48], edge_attr=[48, 4], y=[1, 19], pos=[23, 3], idx=[1], name='gdb_63959', z=[23]),
#  Data(x=[21, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_122662', z=[21]),
#  Data(x=[21, 11], edge_index=[2, 44], edge_attr=[44, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_120311', z=[21]),
#  Data(x=[23, 11], edge_index=[2, 46], edge_attr=[46, 4], y=[1, 19], pos=[23, 3], idx=[1], name='gdb_103827', z=[23]),
#  Data(x=[16, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_28814', z=[16]),
#  Data(x=[18, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_48332', z=[18]),
#  Data(x=[23, 11], edge_index=[2, 46], edge_attr=[46, 4], y=[1, 19], pos=[23, 3], idx=[1], name='gdb_112256', z=[23]),
#  Data(x=[19, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_93887', z=[19]),
#  Data(x=[17, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_115124', z=[17]),
#  Data(x=[21, 11], edge_index=[2, 44], edge_attr=[44, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_75715', z=[21]),
#  Data(x=[16, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_82156', z=[16]),
#  Data(x=[13, 11], edge_index=[2, 26], edge_attr=[26, 4], y=[1, 19], pos=[13, 3], idx=[1], name='gdb_131578', z=[13]),
#  Data(x=[19, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_32102', z=[19]),
#  Data(x=[19, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_41317', z=[19]),
#  Data(x=[17, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_77749', z=[17]),
#  Data(x=[16, 11], edge_index=[2, 32], edge_attr=[32, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_64688', z=[16]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_46376', z=[19]),
#  Data(x=[18, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_73642', z=[18]),
#  Data(x=[18, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_105500', z=[18]),
#  Data(x=[17, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_113646', z=[17]),
#  Data(x=[14, 11], edge_index=[2, 28], edge_attr=[28, 4], y=[1, 19], pos=[14, 3], idx=[1], name='gdb_22873', z=[14]),
#  Data(x=[20, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_17358', z=[20]),
#  Data(x=[22, 11], edge_index=[2, 46], edge_attr=[46, 4], y=[1, 19], pos=[22, 3], idx=[1], name='gdb_76411', z=[22]),
#  Data(x=[20, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_27278', z=[20]),
#  Data(x=[17, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_67256', z=[17]),
#  Data(x=[16, 11], edge_index=[2, 30], edge_attr=[30, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_133679', z=[16]),
#  Data(x=[17, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_42370', z=[17]),
#  Data(x=[18, 11], edge_index=[2, 38], edge_attr=[38, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_90418', z=[18]),
#  Data(x=[20, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[20, 3], idx=[1], name='gdb_96112', z=[20]),
#  Data(x=[21, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[21, 3], idx=[1], name='gdb_115486', z=[21]),
#  Data(x=[18, 11], edge_index=[2, 42], edge_attr=[42, 4], y=[1, 19], pos=[18, 3], idx=[1], name='gdb_105935', z=[18]),
#  Data(x=[12, 11], edge_index=[2, 24], edge_attr=[24, 4], y=[1, 19], pos=[12, 3], idx=[1], name='gdb_24741', z=[12]),
#  Data(x=[17, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_124759', z=[17]),
#  Data(x=[17, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_108289', z=[17]),
#  Data(x=[16, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[16, 3], idx=[1], name='gdb_11940', z=[16]),
#  Data(x=[17, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1, 19], pos=[17, 3], idx=[1], name='gdb_112164', z=[17]),
#  Data(x=[19, 11], edge_index=[2, 40], edge_attr=[40, 4], y=[1, 19], pos=[19, 3], idx=[1], name='gdb_89771', z=[19]),
#  ...]

# %% [markdown]
# ## Few Shot learning with new meta-model (MAML)

# %%
# run k-shot to check how rapidly we are able to adapt to unseen tasks
# starting w/ a single unseen task

test_task = GRAPH_TEST[0]
num_k_shots = 10

# use model returned from earlier optimization
inner_loop_optimizer = torch.optim.SGD(model.parameters(), lr = lr_task_specific)
held_out_task_specific_loss, metaTrainLosses, _ = task_specific_train_and_eval(model, test_task, inner_loop_optimizer, num_k_shots)

plt.plot(metaTrainLosses)
plt.xlim([0,num_k_shots])
# Out:
# (0.0, 10.0)
